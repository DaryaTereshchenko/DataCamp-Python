# %%
# plt.plot()
# plt.scatter()
# plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.show()

# %%
"""
When you have a time scale along the horizontal axis, the line plot is your friend. 
But in many other cases, when you're trying to assess if there's a correlation between two variables, for example, the scatter plot is the better choice.
"""
# Out:
# "\nWhen you have a time scale along the horizontal axis, the line plot is your friend. \nBut in many other cases, when you're trying to assess if there's a correlation between two variables, for example, the scatter plot is the better choice.\n"

# %%
# logarthmic scale
plt.xscale('log')

# %%
# HISTOGRAM
# defalut number of bins is 10

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(values, bins=3)
plt.show()

# %%
# Show and clean up plot
plt.show()
plt.clf()

# %%
# CUSTOMIZE PLOT

# %%
import matplotlib.pyplot as plt
year = [1950, 1951, 1952, 2100] 
pop = [2.538, 2.57, 2.62, 10.85]

plt.plot(year, pop)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('World Population Projections')
plt.yticks([0, 2, 4, 6, 8, 10], ['0', '2B', '4B', '6B', '8B', '10B'])
plt.show()

# %%
# costomize the size of the bubbles in the scatter plot
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2)

# %%
# colors of the bubbles 
# Specify c -> color and alpha -> opacity inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha=0.8)

# Add grid() call for the grid lines
plt.grid(True)
