# %% [markdown]
# #Classification

# %%
from sklearn.model_selection import train_test_split
# stratify ensures the target label proportions reflect that of the original dataset.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42, stratify=y)

# plot the model complexity corve of trainning and testing sets while training to see k value gives the most accurate model

# %%
# Create neighbors
neighbors = np.arange(1, 13)
train_accuracies = {}
test_accuracies = {}

for neighbor in neighbors:
  
	# Set up a KNN Classifier
	knn = KNeighborsClassifier(n_neighbors=neighbor)
  
	# Fit the model
	knn.fit(X_train, y_train)
  
	# Compute accuracy
	train_accuracies[neighbor] = knn.score(X_train, y_train)
	test_accuracies[neighbor] = knn.score(X_test, y_test)
print(neighbors, '\n', train_accuracies, '\n', test_accuracies)

# %% [markdown]
# #Regression - continuous variables

# %% [markdown]
# !['image.png'](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Crossvaldation is necessary for model's evaluation. You need to create folds and train the model on each fold and test it on the remaining folds.
# Calculate the scores of each fold then you can calculate the mean of the scores to get the model's accuracy.
# 10 folds = 10-fold cross validation
# k folds = k-fold CV
# to perform cross validation, you need to import cross_val_score from sklearn.model_selection

from sklearn.model_selection import cross_val_score, KFold
kf = KFold(n_splits=10, shuffle=True, random_state=42)
reg = LinearRegression()
cv_results = cross_val_score(reg, X, y, cv=kf, scoring='f1')
